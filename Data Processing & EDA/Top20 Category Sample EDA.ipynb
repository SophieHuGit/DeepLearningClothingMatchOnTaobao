# %% [markdown]
# # EDA of Top20 Category Samples

# %%
import os
import random
from shutil import copyfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread
import pathlib

# %% [markdown]
# ## Distribution of images in filtered data set

# %%
image_folder = ['33', '42', '48', '50', '52', '81', '111', '137', '155', '160',
               '178', '228', '284', '311', '368', '453', '461', '505', '516', '522']
nimgs = {}
for i in image_folder:
    nimages = len(os.listdir('data/filter/'+i+'/'))
    nimgs[i]=nimages
plt.figure(figsize=(10, 8))
plt.bar(range(len(nimgs)), list(nimgs.values()), align='center')
plt.xticks(range(len(nimgs)), list(nimgs.keys()))
plt.title('Distribution of different classes of Filtered Dataset')
plt.show()

# %%
for i in ['33', '42', '48', '50', '52', '81', '111', '137', '155', '160',
          '178', '228', '284', '311', '368', '453', '461', '505', '516', '522']:
    print('Filtered category {} images are: '.format(i)+str(len(os.listdir('data/filter/'+i+'/'))))
# Out:
# Filtered category 33 images are: 3691
# Filtered category 42 images are: 3578
# Filtered category 48 images are: 4693
# Filtered category 50 images are: 2956
# Filtered category 52 images are: 10197
# Filtered category 81 images are: 2232
# Filtered category 111 images are: 6519
# Filtered category 137 images are: 3757
# Filtered category 155 images are: 4258
# Filtered category 160 images are: 3713
# Filtered category 178 images are: 2541
# Filtered category 228 images are: 4154
# Filtered category 284 images are: 7767
# Filtered category 311 images are: 2138
# Filtered category 368 images are: 14168
# Filtered category 453 images are: 2608
# Filtered category 461 images are: 6848
# Filtered category 505 images are: 4795
# Filtered category 516 images are: 3137
# Filtered category 522 images are: 1949

# %% [markdown]
# ## Distributions of image sizes of different categories

# %%
image_folder = ['33', '42', '48', '50', '52', '81', '111', '137', '155', '160',
               '178', '228', '284', '311', '368', '453', '461', '505', '516', '522']

for i in image_folder:
    sample_images = list(pathlib.Path('data/filter/'+i+'/').rglob('*/'))
    np.random.seed(42)
    rand_imgs = np.random.choice(sample_images, size=10*10)

    shapes = []
    for img in rand_imgs:
        shapes.append(imread(str(img)).shape)
    
    shapes = pd.DataFrame().assign(X=pd.Series(shapes).map(lambda s: s[0]), Y=pd.Series(shapes).map(lambda s: s[1]))
    
    plt.figure(figsize=(12, 8))
    sns.set_context("notebook", font_scale=1.5)
    sns.kdeplot(shapes['X'], bw=75)
    sns.kdeplot(shapes['Y'], bw=75)
    plt.title('Distribution of {}_image Sizes'.format(i))
    ax = plt.gca()
    ax.set_xlim(0, ax.get_xlim()[1])

# %% [markdown]
# ## Distribution of images in training data set

# %%
image_folder = ['33', '42', '48', '50', '52', '81', '111', '137', '155', '160',
               '178', '228', '284', '311', '368', '453', '461', '505', '516', '522']
nimgs = {}
for i in image_folder:
    nimages = len(os.listdir('data/training/'+i+'/'))
    nimgs[i]=nimages
plt.figure(figsize=(9, 6))
plt.bar(range(len(nimgs)), list(nimgs.values()), align='center')
plt.xticks(range(len(nimgs)), list(nimgs.keys()))
plt.title('Distribution of different classes in Training Dataset')
plt.show()

# %%
for i in ['33', '42', '48', '50', '52', '81', '111', '137', '155', '160',
          '178', '228', '284', '311', '368', '453', '461', '505', '516', '522']:
    print('Filtered category {} images are: '.format(i)+str(len(os.listdir('data/training/'+i+'/'))))
# Out:
# Filtered category 33 images are: 2615
# Filtered category 42 images are: 2561
# Filtered category 48 images are: 3364
# Filtered category 50 images are: 2150
# Filtered category 52 images are: 7280
# Filtered category 81 images are: 1605
# Filtered category 111 images are: 4766
# Filtered category 137 images are: 2761
# Filtered category 155 images are: 3054
# Filtered category 160 images are: 2652
# Filtered category 178 images are: 1833
# Filtered category 228 images are: 2953
# Filtered category 284 images are: 5625
# Filtered category 311 images are: 1526
# Filtered category 368 images are: 10234
# Filtered category 453 images are: 1869
# Filtered category 461 images are: 4889
# Filtered category 505 images are: 3499
# Filtered category 516 images are: 2259
# Filtered category 522 images are: 1409

# %% [markdown]
# ## Distribution of images in validation data set

# %%
image_folder = ['33', '42', '48', '50', '52', '81', '111', '137', '155', '160',
               '178', '228', '284', '311', '368', '453', '461', '505', '516', '522']
nimgs = {}
for i in image_folder:
    nimages = len(os.listdir('data/validation/'+i+'/'))
    nimgs[i]=nimages
plt.figure(figsize=(9, 6))
plt.bar(range(len(nimgs)), list(nimgs.values()), align='center')
plt.xticks(range(len(nimgs)), list(nimgs.keys()))
plt.title('Distribution of different classes in Validation Dataset')
plt.show()

# %%
for i in ['33', '42', '48', '50', '52', '81', '111', '137', '155', '160',
          '178', '228', '284', '311', '368', '453', '461', '505', '516', '522']:
    print('Filtered category {} images are: '.format(i)+str(len(os.listdir('data/validation/'+i+'/'))))
# Out:
# Filtered category 33 images are: 289
# Filtered category 42 images are: 290
# Filtered category 48 images are: 382
# Filtered category 50 images are: 249
# Filtered category 52 images are: 810
# Filtered category 81 images are: 159
# Filtered category 111 images are: 507
# Filtered category 137 images are: 314
# Filtered category 155 images are: 351
# Filtered category 160 images are: 325
# Filtered category 178 images are: 198
# Filtered category 228 images are: 332
# Filtered category 284 images are: 608
# Filtered category 311 images are: 163
# Filtered category 368 images are: 1100
# Filtered category 453 images are: 200
# Filtered category 461 images are: 562
# Filtered category 505 images are: 385
# Filtered category 516 images are: 276
# Filtered category 522 images are: 155

# %% [markdown]
# ## Distribution of images in testing data set

# %%
image_folder = ['33', '42', '48', '50', '52', '81', '111', '137', '155', '160',
               '178', '228', '284', '311', '368', '453', '461', '505', '516', '522']
nimgs = {}
for i in image_folder:
    nimages = len(os.listdir('data/testing/'+i+'/'))
    nimgs[i]=nimages
plt.figure(figsize=(9, 6))
plt.bar(range(len(nimgs)), list(nimgs.values()), align='center')
plt.xticks(range(len(nimgs)), list(nimgs.keys()))
plt.title('Distribution of different classes in Testing Dataset')
plt.show()

# %%
for i in ['33', '42', '48', '50', '52', '81', '111', '137', '155', '160',
          '178', '228', '284', '311', '368', '453', '461', '505', '516', '522']:
    print('Filtered category {} images are: '.format(i)+str(len(os.listdir('data/testing/'+i+'/'))))
# Out:
# Filtered category 33 images are: 787
# Filtered category 42 images are: 727
# Filtered category 48 images are: 947
# Filtered category 50 images are: 557
# Filtered category 52 images are: 2107
# Filtered category 81 images are: 468
# Filtered category 111 images are: 1246
# Filtered category 137 images are: 682
# Filtered category 155 images are: 853
# Filtered category 160 images are: 736
# Filtered category 178 images are: 510
# Filtered category 228 images are: 869
# Filtered category 284 images are: 1534
# Filtered category 311 images are: 449
# Filtered category 368 images are: 2834
# Filtered category 453 images are: 539
# Filtered category 461 images are: 1397
# Filtered category 505 images are: 911
# Filtered category 516 images are: 602
# Filtered category 522 images are: 385
